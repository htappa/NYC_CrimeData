# %% [markdown]
# ### Load dataset

# %%
import pandas as pd

# Load the data
df = pd.read_csv('NYPD2.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-ad25cb3ff645> in <module>()
#       2
#       3 # Load the data
# ----> 4 df = pd.read_csv('NYPD2.csv')
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     438
#     439     # Create the parser.
# --> 440     parser = TextFileReader(filepath_or_buffer, **kwds)
#     441
#     442     if chunksize or iterator:
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     785             self.options['has_index_names'] = kwds['has_index_names']
#     786
# --> 787         self._make_engine(self.engine)
#     788
#     789     def close(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1012     def _make_engine(self, engine='c'):
#    1013         if engine == 'c':
# -> 1014             self._engine = CParserWrapper(self.f, **self.options)
#    1015         else:
#    1016             if engine == 'python':
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1706         kwds['usecols'] = self.usecols
#    1707
# -> 1708         self._reader = parsers.TextReader(src, **kwds)
#    1709
#    1710         passed_names = self.names is None
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'NYPD2.csv' does not exist

# %% [markdown]
# ### Remove rows with missing value

# %%
import numpy as np

print('Number of rows before removing rows with missing values: ' + str(df.shape[0]))

# Remove rows with np.NaN
df.dropna(how='any', inplace=True)

print('Number of rows after removing rows with missing values: ' + str(df.shape[0]))
# Out:
# Number of rows before removing rows with missing values: 31710
# Number of rows after removing rows with missing values: 31585

# %% [markdown]
# ### Get the feature and target vector

# %%
# Get the feature vector
X = df.drop('CRM_ATPT_CPTD_CD', axis = 1)

# Get the target vector
y = df['CRM_ATPT_CPTD_CD']

print(X.shape)
print(y.shape)
# Out:
# (31585, 10)
# (31585,)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
y = le.fit_transform(y)

# %%
class MultiColumnLabelEncoder:
    def __init__(self,columns = None):
        self.columns = columns # array of column names to encode

    def fit(self,X,y=None):
        return self # not relevant here

    def transform(self,X):
        '''
        Transforms columns of X specified in self.columns using
        LabelEncoder(). If no columns specified, transforms all
        columns in X.
        '''
        output = X.copy()
        if self.columns is not None:
            for col in self.columns:
                output[col] = LabelEncoder().fit_transform(output[col])
        else:
            for colname,col in output.iteritems():
                output[colname] = LabelEncoder().fit_transform(col)
        return output

    def fit_transform(self,X,y=None):
        return self.fit(X,y).transform(X)

# %%
MultiColumnLabelEncoder(columns = ['LAW_CAT_CD','SUSP_SEX','OFNS_DESC','PD_DESC']).fit_transform(X)
# Out:
#        LAW_CAT_CD  OFNS_DESC  PD_DESC               PREM_TYP_DESC  \
# 0               1         26        5             RESIDENCE-HOUSE
# 1               2         19       55  RESIDENCE - PUBLIC HOUSING
# 2               0          7      126  RESIDENCE - PUBLIC HOUSING
# 3               2         19       55      RESIDENCE - APT. HOUSE
# 4               2         19       55             RESIDENCE-HOUSE
# 5               0         13        9      RESIDENCE - APT. HOUSE
# 6               2         19       55      RESIDENCE - APT. HOUSE
# 7               1         27      196  RESIDENCE - PUBLIC HOUSING
# 8               2         19       55      RESIDENCE - APT. HOUSE
# 9               2         19       55      RESIDENCE - APT. HOUSE
# 10              2         19       54  RESIDENCE - PUBLIC HOUSING
# 11              2         19       55                      STREET
# 12              2         19       55             RESIDENCE-HOUSE
# 13              1          3       10      RESIDENCE - APT. HOUSE
# 14              0         17       87        TRANSIT - NYC SUBWAY
# 15              2         19       55      RESIDENCE - APT. HOUSE
# 16              1         21       63                      STREET
# 17              1          3       10                      STREET
# 18              2         19       55             RESIDENCE-HOUSE
# 19              1          3      121              GROCERY/BODEGA
# 20              0         13        9      RESIDENCE - APT. HOUSE
# 21              2         19       55      RESIDENCE - APT. HOUSE
# 22              0         13        9  RESIDENCE - PUBLIC HOUSING
# 23              0         36      161                      STREET
# 24              1          3       10                      STREET
# 25              2         19       55      RESIDENCE - APT. HOUSE
# 26              2         19       55      RESIDENCE - APT. HOUSE
# 27              1          3      131             RESIDENCE-HOUSE
# 28              1          3       10             RESIDENCE-HOUSE
# 29              1          3       10      RESIDENCE - APT. HOUSE
# ...           ...        ...      ...                         ...
# 31680           0         13        9                      STREET
# 31681           0         36      166                      STREET
# 31682           1          3       10      RESIDENCE - APT. HOUSE
# 31683           1          3       10      RESIDENCE - APT. HOUSE
# 31684           1         37       28      RESIDENCE - APT. HOUSE
# 31685           1         26        5             RESIDENCE-HOUSE
# 31686           1          3       10  RESIDENCE - PUBLIC HOUSING
# 31687           0         24       40             RESIDENCE-HOUSE
# 31688           1         39      194             RESIDENCE-HOUSE
# 31689           0         13      183  RESIDENCE - PUBLIC HOUSING
# 31690           2         19       55             RESIDENCE-HOUSE
# 31691           1         39      194      RESIDENCE - APT. HOUSE
# 31692           2         19       55      RESIDENCE - APT. HOUSE
# 31693           1         32      106      RESIDENCE - APT. HOUSE
# 31694           2         19       55      RESIDENCE - APT. HOUSE
# 31695           0         18       97                      STREET
# 31696           2         19       55      RESIDENCE - APT. HOUSE
# 31697           2         19       55      RESIDENCE - APT. HOUSE
# 31698           1         26        5      RESIDENCE - APT. HOUSE
# 31699           2         19       55             RESIDENCE-HOUSE
# 31700           1         32      133      RESIDENCE - APT. HOUSE
# 31701           1         32      106  RESIDENCE - PUBLIC HOUSING
# 31702           2         19       55             RESIDENCE-HOUSE
# 31703           1         26        5  RESIDENCE - PUBLIC HOUSING
# 31704           1         32      106      RESIDENCE - APT. HOUSE
# 31705           2         19       54      RESIDENCE - APT. HOUSE
# 31706           1          3       10      RESIDENCE - APT. HOUSE
# 31707           1         37      174            RESTAURANT/DINER
# 31708           2         19       54         COMMERCIAL BUILDING
# 31709           1          3       10      RESIDENCE - APT. HOUSE
#
#       SUSP_AGE_GROUP       SUSP_RACE  SUSP_SEX VIC_AGE_GROUP        VIC_RACE  \
# 0              25-44           BLACK         1         18-24           BLACK
# 1              45-64  WHITE HISPANIC         0         25-44           BLACK
# 2              25-44           BLACK         1         25-44           BLACK
# 3              25-44  WHITE HISPANIC         1         25-44   ASIAN/PAC.ISL
# 4              25-44           BLACK         0         18-24           BLACK
# 5              25-44           BLACK         1         25-44           BLACK
# 6              45-64   ASIAN/PAC.ISL         0         25-44           WHITE
# 7              25-44           BLACK         1         25-44           BLACK
# 8              18-24           BLACK         1         45-64           BLACK
# 9              45-64           BLACK         1           65+           BLACK
# 10             45-64           BLACK         0         45-64           BLACK
# 11             18-24   ASIAN/PAC.ISL         1         18-24   ASIAN/PAC.ISL
# 12             18-24   ASIAN/PAC.ISL         1         45-64   ASIAN/PAC.ISL
# 13             18-24  WHITE HISPANIC         1         45-64  WHITE HISPANIC
# 14             18-24  WHITE HISPANIC         1           <18  WHITE HISPANIC
# 15             25-44           WHITE         1         25-44   ASIAN/PAC.ISL
# 16             25-44   ASIAN/PAC.ISL         1         25-44           WHITE
# 17             18-24  WHITE HISPANIC         1         18-24   ASIAN/PAC.ISL
# 18             25-44           WHITE         1         18-24           WHITE
# 19             25-44           BLACK         1         25-44           BLACK
# 20             25-44           BLACK         0         25-44           BLACK
# 21             25-44           BLACK         0         25-44           BLACK
# 22             18-24           BLACK         1         18-24  WHITE HISPANIC
# 23               <18           BLACK         1         18-24  WHITE HISPANIC
# 24             25-44           BLACK         1         25-44           BLACK
# 25             25-44           BLACK         1         18-24           BLACK
# 26             45-64           WHITE         0           65+           WHITE
# 27             45-64           WHITE         1         45-64           WHITE
# 28             25-44   ASIAN/PAC.ISL         0         25-44   ASIAN/PAC.ISL
# 29             18-24           BLACK         0         18-24  WHITE HISPANIC
# ...              ...             ...       ...           ...             ...
# 31680          45-64  WHITE HISPANIC         0         45-64  WHITE HISPANIC
# 31681          25-44  WHITE HISPANIC         0         25-44           WHITE
# 31682          18-24  BLACK HISPANIC         1           <18  WHITE HISPANIC
# 31683          25-44           WHITE         1         25-44           WHITE
# 31684          45-64  BLACK HISPANIC         1           <18           BLACK
# 31685          45-64           BLACK         1         25-44           BLACK
# 31686          45-64  WHITE HISPANIC         0         45-64  WHITE HISPANIC
# 31687          25-44           BLACK         1         25-44           BLACK
# 31688          25-44           BLACK         1         25-44           BLACK
# 31689          18-24           BLACK         1         18-24           BLACK
# 31690          25-44           BLACK         0         25-44           BLACK
# 31691          18-24           WHITE         0         45-64   ASIAN/PAC.ISL
# 31692          45-64   ASIAN/PAC.ISL         1         45-64   ASIAN/PAC.ISL
# 31693          18-24   ASIAN/PAC.ISL         0         45-64   ASIAN/PAC.ISL
# 31694          45-64           BLACK         1           65+           WHITE
# 31695          45-64           BLACK         1         45-64           BLACK
# 31696          25-44           WHITE         1           65+           WHITE
# 31697          25-44           BLACK         1         45-64  BLACK HISPANIC
# 31698          25-44           BLACK         0         25-44           BLACK
# 31699          45-64           BLACK         0         25-44           BLACK
# 31700          25-44  WHITE HISPANIC         0         18-24  WHITE HISPANIC
# 31701          25-44  BLACK HISPANIC         0         25-44  BLACK HISPANIC
# 31702          25-44           BLACK         1         45-64           BLACK
# 31703          25-44  WHITE HISPANIC         0         25-44  WHITE HISPANIC
# 31704          45-64           BLACK         1         45-64           BLACK
# 31705          45-64   ASIAN/PAC.ISL         1         45-64           BLACK
# 31706          25-44           BLACK         1         25-44           BLACK
# 31707          25-44   ASIAN/PAC.ISL         1         25-44   ASIAN/PAC.ISL
# 31708          25-44   ASIAN/PAC.ISL         0         25-44   ASIAN/PAC.ISL
# 31709            <18  BLACK HISPANIC         1         25-44  BLACK HISPANIC
#
#       VIC_SEX
# 0           F
# 1           F
# 2           F
# 3           M
# 4           F
# 5           M
# 6           F
# 7           F
# 8           M
# 9           M
# 10          M
# 11          F
# 12          M
# 13          F
# 14          M
# 15          F
# 16          M
# 17          M
# 18          F
# 19          M
# 20          F
# 21          M
# 22          M
# 23          M
# 24          M
# 25          M
# 26          F
# 27          F
# 28          F
# 29          M
# ...       ...
# 31680       M
# 31681       M
# 31682       F
# 31683       F
# 31684       M
# 31685       F
# 31686       F
# 31687       F
# 31688       F
# 31689       F
# 31690       M
# 31691       M
# 31692       M
# 31693       F
# 31694       M
# 31695       M
# 31696       F
# 31697       F
# 31698       F
# 31699       M
# 31700       F
# 31701       M
# 31702       F
# 31703       F
# 31704       F
# 31705       M
# 31706       F
# 31707       F
# 31708       F
# 31709       M
#
# [31585 rows x 10 columns]
